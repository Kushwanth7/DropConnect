# %%
from hw3bmnist import *
from hw3bmnist import test_dropconnect
test_dropconnect(learning_rate=0.01, n_epochs=150, nkerns=[32, 64],batch_size=20,
                 verbose=True, fileName = 'MNIST_NoCrop_NoScale_Fully150_p0.5',
                 fullyconnected=150,activation=tanh,p=0.5)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 8.710000 %
#      epoch 1, minibatch 2500/2500, test error of best model 8.910000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# ...

# %%
from hw3bmnist import *
from hw3bmnist import test_dropconnect
test_dropconnect(learning_rate=0.01, n_epochs=200, nkerns=[32, 64],batch_size=20,
                 verbose=True, fileName = 'MNIST_NoCrop_NoScale_Fully150_p0.5',
                 fullyconnected=150,activation=relu,p=0.5)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 8.520000 %
#      epoch 1, minibatch 2500/2500, test error of best model 8.080000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# ...
