# %%
from hw3bmnist import *
from hw3bmnist import test_lenet
test_lenet(learning_rate=0.01, n_epochs=150, nkerns=[32, 64],
            batch_size=20, verbose=True, fileName = 'MNIST_predictions_NoDrop_NoCrop_NOScale',
           fullyconnected=20,activation=relu)
# Out:
# ... building the model
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 5.830000 %
#      epoch 1, minibatch 2500/2500, test error of best model 6.310000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# ...

# %%
from hw3bmnist import *
from hw3bmnist import test_lenet
test_lenet_cropscalrot(learning_rate=0.01, n_epochs=150, nkerns=[32, 64],
            batch_size=20, verbose=True, fileName = 'MNIST_predictions_NoDrop_Crop_Scale_Rot',
           fullyconnected=20,activation=relu)
# Out:
# random 15
# crop over
# x is intialized
# y is intialized
# x is stacked
# y is stacked
# (65000, 576)
# (65000, 1)
# (65000,)
# all is well
# crop over
# crop over
# ... building the model
# ... training
# print(validation_frequency) = 3250
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# ...

# %%
from hw3bmnist import *
from hw3bmnist import test_dropconnect
test_dropconnect(learning_rate=0.01, n_epochs=200, nkerns=[32, 64],
                 batch_size=20, verbose=True, 
                 fileName = 'MNIST_DropConnect_fully50_p0.5_relu',fullyconnected=50,activation=relu,p=0.5)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 10.360000 %
#      epoch 1, minibatch 2500/2500, test error of best model 10.070000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# ...

# %%
from hw3bmnist import test_mlp
from hw3bmnist import *
test_mlp(learning_rate=0.1, L1_reg=0.00, L2_reg=0.0001, n_epochs=200,
             batch_size=20, n_hidden=50, 
             verbose=True, fileName='predictionsMLPrelu',fullyconnected=20,activation=relu)
# Out:
# ... building the model
# Yo man
# Model building complete
# Commpiling the train model function
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 6.540000 %
#      epoch 1, minibatch 2500/2500, test error of best model 6.900000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# ...

# %%
from hw3bsvhn import *
from hw3bsvhn import test_dropconnect
test_dropconnect(learning_rate=0.1, n_epochs=100, nkerns=[64, 128,128],
            batch_size=20, verbose=True, fileName = 'predictions_SVHN_DropConnect',
                 fullyconnected=128,activation=relu,p=0.5)
# Out:
# ... building the model
# Yo man
# Old updates
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# ...
