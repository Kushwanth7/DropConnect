# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bmnist import *
test_dropconnect(batch_size = 20,fileName='dropconnectnormal',nkerns = [32,64],learning_rate = 0.01,verbose=True,n_epochs = 200,activation=relu,fullyconnected=20,p=0.5)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 14.150000 %
#      epoch 1, minibatch 2500/2500, test error of best model 14.380000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# ...

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bmnist import *
test_dropout(batch_size = 20,fileName='dropoutfully=350',nkerns = [32,64],learning_rate = 0.01,verbose=True,n_epochs = 200,activation=relu,fullyconnected=350,p=0.5)
# Out:
# ... building the model
# Yo Man
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 6.980000 %
#      epoch 1, minibatch 2500/2500, test error of best model 7.160000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# ...

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bsvhn import *
test_dropconnect_cropscalrot(batch_size = 20,fileName='svhndropconnect1',nkerns = [32,32,64],learning_rate = 0.1,verbose=True,n_epochs = 200,activation=relu,fullyconnected=128,p=0.5)
# Out:
# random 15
# crop over
# x is intialized
# y is intialized
# x is stacked
# y is stacked
# (85710, 2352)
# (85710, 1)
# (85710,)
# all is well
# crop over
# crop over
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 4285
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# ...

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bsvhn import *
test_dropconnect_cropscalrot(batch_size = 20,fileName='svhndropconnect12',nkerns = [64,64,128],learning_rate = 0.1,verbose=True,n_epochs = 6,activation=relu,fullyconnected=128,p=0.5)
# Out:
# random 15
# crop over
# x is intialized
# y is intialized
# x is stacked
# y is stacked
# (85710, 2352)
# (85710, 1)
# (85710,)
# all is well
# crop over
# crop over
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 4285
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# ...

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bsvhn import *
test_dropconnect_cropscalrot(batch_size = 20,fileName='svhndropconnect123',nkerns = [64,128,256],learning_rate = 0.1,verbose=True,n_epochs = 6,activation=relu,fullyconnected=256,p=0.5)
# Out:
# random 15
# crop over
# x is intialized
# y is intialized
# x is stacked
# y is stacked
# (85710, 2352)
# (85710, 1)
# (85710,)
# all is well
# crop over
# crop over
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 4285
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# ...
