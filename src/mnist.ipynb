# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bmnist import test_lenet
test_lenet(batch_size = 20,nkerns = [32,64],learning_rate = 0.01,verbose=True,n_epochs = 150)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 2500
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# epoch 1, minibatch 2500/2500, validation error 14.560000 %
#      epoch 1, minibatch 2500/2500, test error of best model 15.250000 %
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# training @ iter =  3300
# training @ iter =  3400
# training @ iter =  3500
# training @ iter =  3600
# training @ iter =  3700
# training @ iter =  3800
# training @ iter =  3900
# training @ iter =  4000
# training @ iter =  4100
# training @ iter =  4200
# training @ iter =  4300
# training @ iter =  4400
# training @ iter =  4500
# training @ iter =  4600
# training @ iter =  4700
# training @ iter =  4800
# training @ iter =  4900
# epoch 2, minibatch 2500/2500, validation error 6.720000 %
#      epoch 2, minibatch 2500/2500, test error of best model 6.660000 %
# training @ iter =  5000
# training @ iter =  5100
# training @ iter =  5200
# training @ iter =  5300
# training @ iter =  5400
# training @ iter =  5500
# training @ iter =  5600
# training @ iter =  5700
# training @ iter =  5800
# training @ iter =  5900
# training @ iter =  6000
# training @ iter =  6100
# training @ iter =  6200
# training @ iter =  6300
# training @ iter =  6400
# training @ iter =  6500
# training @ iter =  6600
# training @ iter =  6700
# training @ iter =  6800
# training @ iter =  6900
# training @ iter =  7000
# training @ iter =  7100
# training @ iter =  7200
# training @ iter =  7300
# training @ iter =  7400
# epoch 3, minibatch 2500/2500, validation error 4.410000 %
#      epoch 3, minibatch 2500/2500, test error of best model 4.620000 %
# training @ iter =  7500
# training @ iter =  7600
# training @ iter =  7700
# training @ iter =  7800
# training @ iter =  7900
# training @ iter =  8000
# training @ iter =  8100
# training @ iter =  8200
# training @ iter =  8300
# training @ iter =  8400
# training @ iter =  8500
# training @ iter =  8600
# training @ iter =  8700
# training @ iter =  8800
# training @ iter =  8900
# training @ iter =  9000
# training @ iter =  9100
# training @ iter =  9200
# training @ iter =  9300
# training @ iter =  9400
# training @ iter =  9500
# training @ iter =  9600
# training @ iter =  9700
# training @ iter =  9800
# training @ iter =  9900
# epoch 4, minibatch 2500/2500, validation error 3.490000 %
#      epoch 4, minibatch 2500/2500, test error of best model 3.730000 %
# training @ iter =  10000
# training @ iter =  10100
# training @ iter =  10200
# training @ iter =  10300
# training @ iter =  10400
# training @ iter =  10500
# Using gpu device 0: GRID K520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ffbbfca15728> in <module>()
#       8 from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
#       9 from hw3bmnist import test_lenet
# ---> 10 test_lenet(batch_size = 20,nkerns = [32,64],learning_rate = 0.01,verbose=True,n_epochs = 150)
#
# /home/ubuntu/extern/dropconnect/src/hw3bmnist.py in test_lenet(learning_rate, n_epochs, nkerns, batch_size, verbose, fileName)
#     220
#     221     predictions = train_nn(train_model, validate_model, test_model, getPredictedValue,
# --> 222         n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
#     223
#     224     f = open(fileName, 'wb')
#
# /home/ubuntu/extern/dropconnect/src/hw3_nn.pyc in train_nn(train_model, validate_model, test_model, getPredictedValue, n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
#     635             if (iter % 100 == 0) and verbose:
#     636                 print('training @ iter = ', iter)
# --> 637             cost_ij = train_model(minibatch_index)
#     638
#     639             if (iter + 1) % validation_frequency == 0:
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     766             # default arguments are stored in the closure of `rval`
#     767             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 768                 r = p(n, [x[0] for x in i], o)
#     769                 for o in node.outputs:
#     770                     compute_map[o][0] = True
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/raw_random.pyc in perform(self, node, inputs, out_)
#     250             r = copy(r)
#     251         rout[0] = r
# --> 252         rval = self.fn(r, *(args + [shape]))
#     253         if not isinstance(rval, numpy.ndarray) \
#     254                or str(rval.dtype) != node.outputs[1].type.dtype:
#
# KeyboardInterrupt:

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3b import test_lenet, test_lenet3
test_lenet3(learning_rate=0.1, n_epochs=100, nkerns=[16, 32, 64],
            batch_size=20, verbose=True, fileName = 'predictions')
# Out:
# Using gpu device 0: GRID K520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0d945e34113d> in <module>()
#       9 from hw3b import test_lenet, test_lenet3
#      10 test_lenet3(learning_rate=0.1, n_epochs=100, nkerns=[16, 32, 64],
# ---> 11             batch_size=20, verbose=True, fileName = 'predictions')
#
# /home/ubuntu/extern/dropconnect/src/hw3b.py in test_lenet3(learning_rate, n_epochs, nkerns, batch_size, verbose, fileName)
#     253     rng = numpy.random.RandomState(23455)
#     254
# --> 255     datasets = load_data()
#     256
#     257     train_set_x, train_set_y = datasets[0]
#
# /home/ubuntu/extern/dropconnect/src/hw3_utils.pyc in load_data(ds_rate, theano_shared)
#     109
#     110     if theano_shared:
# --> 111         test_set_x, test_set_y = shared_dataset(test_set)
#     112         valid_set_x, valid_set_y = shared_dataset(valid_set)
#     113         train_set_x, train_set_y = shared_dataset(train_set)
#
# /home/ubuntu/extern/dropconnect/src/hw3_utils.pyc in shared_dataset(data_xy, borrow)
#      29     shared_x = theano.shared(numpy.asarray(data_x,
#      30                                            dtype=theano.config.floatX),
# ---> 31                              borrow=borrow)
#      32     shared_y = theano.shared(numpy.asarray(data_y,
#      33                                            dtype=theano.config.floatX),
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/sharedvalue.pyc in shared(value, name, strict, allow_downcast, **kwargs)
#     206             try:
#     207                 var = ctor(value, name=name, strict=strict,
# --> 208                            allow_downcast=allow_downcast, **kwargs)
#     209                 utils.add_tag_trace(var)
#     210                 return var
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/sandbox/cuda/var.pyc in float32_shared_constructor(value, name, strict, allow_downcast, borrow, broadcastable)
#     201         # type.broadcastable is guaranteed to be a tuple, which this next
#     202         # function requires
# --> 203         deviceval = type_support_filter(value, type.broadcastable, False, None)
#     204
#     205     try:
#
# KeyboardInterrupt:

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3b import test_mlp
test_mlp(batch_size = 20,n_epochs = 150)
# Out:
# ... building the model
# Yo man
# Model building complete
# Commpiling the train model function
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-99c6c153b479> in <module>()
#       8 from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
#       9 from hw3b import test_mlp
# ---> 10 test_mlp(batch_size = 20,n_epochs = 150)
#
# /home/ubuntu/extern/dropconnect/src/hw3b.py in test_mlp(learning_rate, L1_reg, L2_reg, n_epochs, batch_size, n_hidden, verbose, fileName)
#     616
#     617     predictions = train_nn(train_model, validate_model, test_model, getPredictedValue,
# --> 618         n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
#     619
#     620     f = open(fileName, 'wb')
#
# /home/ubuntu/extern/dropconnect/src/hw3_nn.pyc in train_nn(train_model, validate_model, test_model, getPredictedValue, n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
#     635             if (iter % 100 == 0) and verbose:
#     636                 print('training @ iter = ', iter)
# --> 637             cost_ij = train_model(minibatch_index)
#     638
#     639             if (iter + 1) % validation_frequency == 0:
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     766             # default arguments are stored in the closure of `rval`
#     767             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 768                 r = p(n, [x[0] for x in i], o)
#     769                 for o in node.outputs:
#     770                     compute_map[o][0] = True
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/raw_random.pyc in perform(self, node, inputs, out_)
#     250             r = copy(r)
#     251         rout[0] = r
# --> 252         rval = self.fn(r, *(args + [shape]))
#     253         if not isinstance(rval, numpy.ndarray) \
#     254                or str(rval.dtype) != node.outputs[1].type.dtype:
#
# KeyboardInterrupt:

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3b import test_mlp
load_data(theano_shared=False)
# Out:
# [[array([[ 0.12941176,  0.11764706,  0.14901961, ...,  0.40392157,
#            0.41568627,  0.30980392],
#          [ 0.32941176,  0.29803922,  0.23137255, ...,  0.40392157,
#            0.38431373,  0.31372549],
#          [ 0.0745098 ,  0.21176471,  0.43137255, ...,  0.24705882,
#            0.56862745,  0.90588235],
#          ...,
#          [ 0.47843137,  0.47843137,  0.51764706, ...,  0.21176471,
#            0.20784314,  0.38039216],
#          [ 0.41568627,  0.43921569,  0.56470588, ...,  0.54117647,
#            0.53333333,  0.48235294],
#          [ 0.87058824,  0.90588235,  0.90196078, ...,  0.8627451 ,
#            0.88627451,  0.88627451]]),
#   array([1, 9, 2, ..., 2, 4, 1], dtype=uint8)],
#  [array([[ 0.8627451 ,  0.88627451,  0.87843137, ...,  0.88235294,
#            0.89803922,  0.90196078],
#          [ 0.86666667,  0.90196078,  0.88235294, ...,  0.8627451 ,
#            0.89803922,  0.89411765],
#          [ 0.58431373,  0.49411765,  0.43921569, ...,  0.23137255,
#            0.17254902,  0.14509804],
#          ...,
#          [ 0.36078431,  0.30588235,  0.39607843, ...,  0.85490196,
#            0.85098039,  0.85490196],
#          [ 0.74509804,  0.7372549 ,  0.74901961, ...,  0.85490196,
#            0.83529412,  0.81960784],
#          [ 0.84705882,  0.85098039,  0.83137255, ...,  0.70980392,
#            0.69803922,  0.67058824]]),
#   array([8, 8, 6, ..., 1, 6, 9], dtype=uint8)],
#  (array([[ 0.14901961,  0.40392157,  0.23529412, ...,  0.16470588,
#            0.44313725,  0.27843137],
#          [ 0.50588235,  0.55686275,  0.6       , ...,  0.48235294,
#            0.50980392,  0.61176471],
#          [ 0.58823529,  0.62745098,  0.6627451 , ...,  0.59607843,
#            0.65882353,  0.71764706],
#          ...,
#          [ 0.45098039,  0.51764706,  0.55686275, ...,  0.56470588,
#            0.61568627,  0.64705882],
#          [ 0.37647059,  0.25490196,  0.18431373, ...,  0.40784314,
#            0.33333333,  0.26666667],
#          [ 0.39607843,  0.29411765,  0.23529412, ...,  0.4       ,
#            0.27843137,  0.19607843]]),
#   array([5, 2, 1, ..., 7, 6, 7], dtype=uint8))]

# %%
load_data(theano_shared=False)[0][0]
# Out:
# array([[ 0.12941176,  0.11764706,  0.14901961, ...,  0.40392157,
#          0.41568627,  0.30980392],
#        [ 0.32941176,  0.29803922,  0.23137255, ...,  0.40392157,
#          0.38431373,  0.31372549],
#        [ 0.0745098 ,  0.21176471,  0.43137255, ...,  0.24705882,
#          0.56862745,  0.90588235],
#        ...,
#        [ 0.47843137,  0.47843137,  0.51764706, ...,  0.21176471,
#          0.20784314,  0.38039216],
#        [ 0.41568627,  0.43921569,  0.56470588, ...,  0.54117647,
#          0.53333333,  0.48235294],
#        [ 0.87058824,  0.90588235,  0.90196078, ...,  0.8627451 ,
#          0.88627451,  0.88627451]])

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data_cifar
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3b import test_mlp
load_data_cifar(theano_shared=False)
# Out:
# Using gpu device 0: GRID K520
# [[array([[ 59,  43,  50, ..., 140,  84,  72],
#          [154, 126, 105, ..., 139, 142, 144],
#          [255, 253, 253, ...,  83,  83,  84],
#          ...,
#          [ 69,  62,  58, ...,  91,  87, 100],
#          [158, 158, 158, ...,  54,  68,  74],
#          [196, 196, 193, ..., 165, 167, 166]], dtype=uint8), array([[6],
#          [9],
#          [9],
#          ...,
#          [4],
#          [8],
#          [9]], dtype=uint8)], [array([[140, 146, 143, ...,  78,  64,  78],
#          [100, 122,  87, ..., 160, 158, 150],
#          [ 19,  21,  27, ...,  85,  64,  58],
#          ...,
#          [ 71,  60,  74, ...,  68,  69,  68],
#          [250, 254, 211, ..., 215, 255, 254],
#          [ 62,  61,  60, ..., 130, 130, 131]], dtype=uint8), array([[4],
#          [2],
#          [2],
#          [9],
#          [0],
#          [3],
#          [3],
#          [1],
#          [3],
#          [0],
#          [4],
#          [2],
#          [1],
#          [4],
#          [0],
#          [8],
#          [2],
#          [1],
#          [4],
#          [4],
#          [3],
#          [6],
#          [6],
#          [8],
#          [3],
#          [9],
#          [9],
#          [9],
#          [9],
#          [6],
#          [5],
#          [0],
#          [8],
#          [2],
#          [3],
#          [5],
#          [9],
#          [8],
#          [2],
#          [8],
#          [3],
#          [4],
#          [1],
#          [1],
#          [7],
#          [6],
#          [9],
#          [2],
#          [1],
#          [4],
#          [6],
#          [3],
#          [3],
#          [2],
#          [1],
#          [8],
#          [1],
#          [0],
#          [0],
#          [0],
#          [3],
#          [4],
#          [0],
#          [8],
#          [0],
#          [9],
#          [1],
#          [2],
#          [8],
#          [0],
#          [1],
#          [7],
#          [7],
#          [3],
#          [4],
#          [7],
#          [8],
#          [0],
#          [2],
#          [7],
#          [1],
#          [3],
#          [7],
#          [4],
#          [6],
#          [1],
#          [7],
#          [6],
#          [1],
#          [2],
#          [6],
#          [9],
#          [8],
#          [2],
#          [0],
#          [1],
#          [0],
#          [9],
#          [6],
#          [5],
#          [3],
#          [2],
#          [4],
#          [6],
#          [5],
#          [4],
#          [9],
#          [3],
#          [8],
#          [8],
#          [7],
#          [3],
#          [6],
#          [1],
#          [2],
#          [9],
#          [8],
#          [8],
#          [1],
#          [0],
#          [3],
#          [0],
#          [8],
#          [0],
#          [0],
#          [6],
#          [6],
#          [1],
#          [3],
#          [3],
#          [6],
#          [6],
#          [5],
#          [7],
#          [5],
#          [3],
#          [8],
#          [2],
#          [1],
#          [9],
#          [0],
#          [4],
#          [6],
#          [9],
#          [2],
#          [3],
#          [9],
#          [4],
#          [1],
#          [4],
#          [2],
#          [2],
#          [3],
#          [4],
#          [8],
#          [4],
#          [3],
#          [0],
#          [6],
#          [8],
#          [8],
#          [6],
#          [2],
#          [3],
#          [3],
#          [7],
#          [3],
#          [5],
#          [2],
#          [9],
#          [6],
#          [0],
#          [2],
#          [3],
#          [5],
#          [2],
#          [4],
#          [9],
#          [5],
#          [1],
#          [6],
#          [0],
#          [3],
#          [3],
#          [7],
#          [3],
#          [7],
#          [9],
#          [8],
#          [1],
#          [5],
#          [2],
#          [8],
#          [0],
#          [2],
#          [9],
#          [5],
#          [6],
#          [6],
#          [2],
#          [6],
#          [7],
#          [4],
#          [2],
#          [4],
#          [5],
#          [8],
#          [7],
#          [6],
#          [1],
#          [1],
#          [9],
#          [5],
#          [9],
#          [7],
#          [2],
#          [1],
#          [2],
#          [9],
#          [6],
#          [8],
#          [0],
#          [3],
#          [7],
#          [7],
#          [7],
#          [8],
#          [2],
#          [3],
#          [9],
#          [0],
#          [4],
#          [1],
#          [6],
#          [4],
#          [5],
#          [0],
#          [6],
#          [6],
#          [7],
#          [2],
#          [6],
#          [9],
#          [7],
#          [9],
#          [6],
#          [6],
#          [1],
#          [3],
#          [2],
#          [4],
#          [1],
#          [1],
#          [0],
#          [4],
#          [2],
#          [6],
#          [0],
#          [8],
#          [4],
#          [4],
#          [9],
#          [8],
#          [1],
#          [5],
#          [8],
#          [1],
#          [1],
#          [8],
#          [8],
#          [9],
#          [7],
#          [2],
#          [4],
#          [5],
#          [6],
#          [4],
#          [9],
#          [6],
#          [7],
#          [5],
#          [0],
#          [8],
#          [3],
#          [5],
#          [4],
#          [5],
#          [0],
#          [5],
#          [0],
#          [2],
#          [3],
#          [0],
#          [3],
#          [7],
#          [5],
#          [0],
#          [2],
#          [3],
#          [2],
#          [3],
#          [5],
#          [9],
#          [6],
#          [3],
#          [3],
#          [8],
#          [3],
#          [9],
#          [1],
#          [7],
#          [3],
#          [0],
#          [2],
#          [0],
#          [7],
#          [5],
#          [1],
#          [1],
#          [2],
#          [6],
#          [6],
#          [1],
#          [6],
#          [8],
#          [0],
#          [8],
#          [1],
#          [0],
#          [7],
#          [2],
#          [7],
#          [3],
#          [2],
#          [3],
#          [1],
#          [9],
#          [5],
#          [3],
#          [6],
#          [9],
#          [2],
#          [4],
#          [3],
#          [8],
#          [3],
#          [8],
#          [7],
#          [2],
#          [4],
#          [2],
#          [8],
#          [4],
#          [4],
#          [2],
#          [5],
#          [6],
#          [3],
#          [9],
#          [4],
#          [6],
#          [7],
#          [0],
#          [4],
#          [4],
#          [1],
#          [8],
#          [6],
#          [2],
#          [7],
#          [4],
#          [3],
#          [1],
#          [0],
#          [7],
#          [0],
#          [9],
#          [5],
#          [8],
#          [0],
#          [1],
#          [6],
#          [9],
#          [5],
#          [0],
#          [0],
#          [2],
#          [8],
#          [5],
#          [4],
#          [0],
#          [5],
#          [1],
#          [3],
#          [3],
#          [4],
#          [9],
#          [5],
#          [3],
#          [3],
#          [1],
#          [0],
#          [1],
#          [2],
#          [2],
#          [3],
#          [6],
#          [1],
#          [2],
#          [7],
#          [8],
#          [1],
#          [9],
#          [0],
#          [6],
#          [8],
#          [6],
#          [0],
#          [8],
#          [9],
#          [2],
#          [3],
#          [7],
#          [6],
#          [2],
#          [9],
#          [8],
#          [8],
#          [6],
#          [3],
#          [0],
#          [6],
#          [9],
#          [5],
#          [9],
#          [0],
#          [7],
#          [2],
#          [0],
#          [1],
#          [2],
#          [4],
#          [1],
#          [7],
#          [5],
#          [5],
#          [2],
#          [9],
#          [2],
#          [0],
#          [5],
#          [7],
#          [4],
#          [7],
#          [7],
#          [2],
#          [7],
#          [6],
#          [5],
#          [1],
#          [5],
#          [9],
#          [7],
#          [2],
#          [0],
#          [8],
#          [9],
#          [8],
#          [6],
#          [8],
#          [5],
#          [0],
#          [7],
#          [7],
#          [8],
#          [2],
#          [1],
#          [6],
#          [1],
#          [3],
#          [1],
#          [6],
#          [6],
#          [8],
#          [2],
#          [3],
#          [7],
#          [9],
#          [8],
#          [3],
#          [8],
#          [5],
#          [7],
#          [0],
#          [1],
#          [0],
#          [7],
#          [4],
#          [2],
#          [0],
#          [4],
#          [9],
#          [4],
#          [2],
#          [7],
#          [7],
#          [4],
#          [4],
#          [1],
#          [1],
#          [0],
#          [9],
#          [0],
#          [9],
#          [8],
#          [6],
#          [4],
#          [7],
#          [2],
#          [2],
#          [2],
#          [6],
#          [0],
#          [2],
#          [1],
#          [0],
#          [2],
#          [8],
#          [4],
#          [4],
#          [6],
#          [5],
#          [9],
#          [0],
#          [1],
#          [1],
#          [8],
#          [5],
#          [1],
#          [1],
#          [8],
#          [9],
#          [0],
#          [6],
#          [4],
#          [8],
#          [4],
#          [5],
#          [7],
#          [1],
#          [4],
#          [6],
#          [2],
#          [2],
#          [6],
#          [8],
#          [2],
#          [9],
#          [2],
#          [2],
#          [7],
#          [1],
#          [4],
#          [5],
#          [3],
#          [1],
#          [0],
#          [8],
#          [4],
#          [4],
#          [3],
#          [7],
#          [8],
#          [9],
#          [3],
#          [6],
#          [1],
#          [2],
#          [1],
#          [2],
#          [2],
#          [7],
#          [1],
#          [1],
#          [1],
#          [2],
#          [5],
#          [7],
#          [2],
#          [2],
#          [7],
#          [3],
#          [4],
#          [4],
#          [5],
#          [1],
#          [0],
#          [2],
#          [9],
#          [8],
#          [3],
#          [9],
#          [1],
#          [2],
#          [0],
#          [5],
#          [9],
#          [5],
#          [9],
#          [3],
#          [1],
#          [0],
#          [3],
#          [3],
#          [0],
#          [4],
#          [0],
#          [8],
#          [4],
#          [0],
#          [1],
#          [7],
#          [5],
#          [8],
#          [3],
#          [6],
#          [9],
#          [8],
#          [7],
#          [2],
#          [8],
#          [2],
#          [3],
#          [4],
#          [5],
#          [2],
#          [6],
#          [7],
#          [4],
#          [2],
#          [7],
#          [5],
#          [5],
#          [4],
#          [8],
#          [8],
#          [1],
#          [3],
#          [8],
#          [5],
#          [4],
#          [8],
#          [9],
#          [6],
#          [9],
#          [4],
#          [3],
#          [0],
#          [1],
#          [2],
#          [2],
#          [4],
#          [6],
#          [8],
#          [8],
#          [5],
#          [0],
#          [3],
#          [1],
#          [8],
#          [3],
#          [0],
#          [7],
#          [9],
#          [8],
#          [8],
#          [9],
#          [5],
#          [2],
#          [6],
#          [4],
#          [6],
#          [8],
#          [9],
#          [8],
#          [4],
#          [8],
#          [0],
#          [5],
#          [7],
#          [1],
#          [4],
#          [8],
#          [8],
#          [3],
#          [4],
#          [0],
#          [0],
#          [5],
#          [8],
#          [3],
#          [9],
#          [3],
#          [5],
#          [9],
#          [9],
#          [6],
#          [5],
#          [8],
#          [6],
#          [3],
#          [7],
#          [2],
#          [4],
#          [0],
#          [9],
#          [2],
#          [1],
#          [0],
#          [7],
#          [3],
#          [9],
#          [8],
#          [8],
#          [4],
#          [7],
#          [7],
#          [6],
#          [9],
#          [5],
#          [8],
#          [4],
#          [6],
#          [2],
#          [2],
#          [7],
#          [6],
#          [3],
#          [3],
#          [9],
#          [2],
#          [7],
#          [6],
#          [8],
#          [1],
#          [1],
#          [5],
#          [8],
#          [5],
#          [4],
#          [4],
#          [0],
#          [3],
#          [6],
#          [1],
#          [0],
#          [6],
#          [2],
#          [6],
#          [0],
#          [3],
#          [4],
#          [6],
#          [2],
#          [6],
#          [1],
#          [1],
#          [0],
#          [7],
#          [6],
#          [5],
#          [4],
#          [5],
#          [7],
#          [1],
#          [4],
#          [4],
#          [4],
#          [7],
#          [4],
#          [4],
#          [1],
#          [4],
#          [3],
#          [6],
#          [6],
#          [8],
#          [9],
#          [6],
#          [7],
#          [2],
#          [4],
#          [3],
#          [5],
#          [3],
#          [7],
#          [8],
#          [6],
#          [2],
#          [0],
#          [0],
#          [0],
#          [2],
#          [2],
#          [5],
#          [7],
#          [1],
#          [9],
#          [6],
#          [1],
#          [9],
#          [5],
#          [9],
#          [0],
#          [6],
#          [5],
#          [4],
#          [3],
#          [8],
#          [0],
#          [6],
#          [7],
#          [1],
#          [7],
#          [4],
#          [9],
#          [8],
#          [2],
#          [6],
#          [7],
#          [3],
#          [0],
#          [5],
#          [6],
#          [7],
#          [5],
#          [7],
#          [1],
#          [6],
#          [6],
#          [4],
#          [3],
#          [3],
#          [9],
#          [8],
#          [4],
#          [3],
#          [6],
#          [4],
#          [1],
#          [6],
#          [7],
#          [4],
#          [0],
#          [1],
#          [6],
#          [3],
#          [1],
#          [2],
#          [0],
#          [0],
#          [8],
#          [6],
#          [1],
#          [6],
#          [3],
#          [8],
#          [5],
#          [0],
#          [9],
#          [1],
#          [5],
#          [4],
#          [4],
#          [0],
#          [5],
#          [2],
#          [6],
#          [1],
#          [5],
#          [9],
#          [0],
#          [8],
#          [8],
#          [1],
#          [4],
#          [9],
#          [4],
#          [4],
#          [1],
#          [0],
#          [7],
#          [3],
#          [9],
#          [1],
#          [0],
#          [2],
#          [3],
#          [1],
#          [5],
#          [2],
#          [6],
#          [9],
#          [2],
#          [3],
#          [0],
#          [7],
#          [4],
#          [3],
#          [3],
#          [0],
#          [9],
#          [3],
#          [8],
#          [3],
#          [4],
#          [2],
#          [2],
#          [1],
#          [9],
#          [0],
#          [2],
#          [8],
#          [6],
#          [6],
#          [0],
#          [3],
#          [3],
#          [6],
#          [5],
#          [3],
#          [4],
#          [1],
#          [2],
#          [0],
#          [8],
#          [9],
#          [4],
#          [1],
#          [7],
#          [2],
#          [6],
#          [1],
#          [3],
#          [3],
#          [0],
#          [1],
#          [9],
#          [5],
#          [4],
#          [4],
#          [8],
#          [2],
#          [6],
#          [2],
#          [9],
#          [7],
#          [7],
#          [7],
#          [9],
#          [8],
#          [9],
#          [4],
#          [4],
#          [7],
#          [1],
#          [0],
#          [4],
#          [3],
#          [6],
#          [3],
#          [9],
#          [8],
#          [3],
#          [6],
#          [8],
#          [3],
#          [6],
#          [6],
#          [2],
#          [6],
#          [7],
#          [3],
#          [0],
#          [0],
#          [0],
#          [2],
#          [5],
#          [1],
#          [2],
#          [9],
#          [2],
#          [2],
#          [1],
#          [6],
#          [3],
#          [9],
#          [1],
#          [1],
#          [5]], dtype=uint8)], [array([[158, 159, 165, ..., 124, 129, 110],
#          [235, 231, 232, ..., 178, 191, 199],
#          [158, 158, 139, ...,   8,   3,   7],
#          ...,
#          [ 20,  19,  15, ...,  50,  53,  47],
#          [ 25,  15,  23, ...,  80,  81,  80],
#          [ 73,  98,  99, ...,  94,  58,  26]], dtype=uint8), array([[3],
#          [8],
#          [8],
#          ...,
#          [5],
#          [1],
#          [7]], dtype=uint8)]]

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data_cifar
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3b import test_mlp
load_data_cifar(theano_shared=False)[0][0].shape
# Out:
# (36000, 3072)

# %%
import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import downsample

from hw3_utils import shared_dataset, load_data, load_data_cifar
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn, DropConnect
from hw3bcifar import test_lenet
test_lenet(learning_rate=0.01, n_epochs=100, nkerns=[16,32],
            batch_size=20, verbose=True, fileName = 'predictions')
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 450
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =

# %%
datasets = load_data_cifar()

# %%
train_set_x, train_set_y = datasets[0]

# %%
train_set_y
# Out:
# Elemwise{Cast{int32}}.0
