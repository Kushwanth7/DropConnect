# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 50.327869 %
# ...

# %% [markdown]
# The above was run with batch size =20 and nkerns[0] = 16 and nkerns[1] = 32 and improvement_threshold=0.95

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 49.549180 %
# ...

# %% [markdown]
# The above was run with batch size =20 and nkerns[0] = 16 and nkerns[1] = 64 and improvement_threshold=0.5

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 42.554645 %
# ...

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 44.207650 %
# ...

# %%
from dropOut import test_dropout
test_dropout(batch_size=20,verbose=True)
# Out:
# ... building the model
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 59.071038 %
# ...
