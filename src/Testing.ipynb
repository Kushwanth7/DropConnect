# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20,n_epochs=3)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 45.355191 %
# ...

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20,n_epochs=3)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 43.292350 %
# ...

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20,n_epochs=1)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# epoch 1, minibatch 3296/3296, validation error 43.032787 %
# ...

# %%
f = open('predictions', 'rb')
import cPickle, gzip, numpy
predictionList = cPickle.load(f)

# %%
print(predictionList)
# Out:
# [array([2, 2, 1, 0, 6, 4, 3, 1, 1, 6, 1, 6, 9, 7, 4, 4, 1, 6, 3, 4]), array([2, 0, 1, 3, 2, 5, 4, 1, 4, 1, 6, 3, 6, 4, 6, 1, 5, 1, 1, 2]), array([9, 1, 6, 1, 2, 9, 1, 1, 7, 6, 9, 2, 5, 1, 8, 4, 8, 1, 7, 0]), array([2, 0, 2, 4, 1, 1, 6, 9, 1, 0, 0, 0, 3, 1, 1, 6, 2, 4, 3, 1]), array([4, 7, 2, 7, 2, 1, 7, 1, 8, 1, 0, 4, 6, 4, 6, 4, 7, 1, 7, 7]), array([1, 8, 2, 2, 4, 2, 1, 1, 8, 6, 3, 5, 0, 2, 3, 2, 2, 7, 0, 2]), array([8, 8, 1, 7, 2, 4, 3, 4, 2, 8, 6, 1, 3, 0, 8, 2, 0, 1, 7, 7]), array([7, 1, 4, 6, 7, 2, 1, 1, 6, 3, 1, 6, 5, 1, 9, 1, 7, 6, 4, 6]), array([4, 7, 3, 6, 1, 4, 1, 9, 0, 2, 7, 1, 2, 2, 1, 4, 0, 9, 6, 2]), array([1, 0, 0, 1, 4, 8, 3, 2, 1, 0, 2, 6, 1, 7, 7, 3, 6, 1, 1, 3]), array([1, 2, 3, 4, 6, 2, 1, 0, 4, 7, 1, 0, 7, 3, 7, 3, 1, 1, 1, 2]), array([0, 0, 7, 7, 1, 0, 4, 2, 2, 9, 2, 5, 7, 4, 1, 3, 0, 4, 5, 7]), array([7, 4, 0, 0, 1, 7, 2, 0, 2, 0, 7, 9, 0, 3, 0, 3, 1, 1, 2, 6]), array([1, 7, 4, 3, 0, 0, 4, 7, 6, 1, 7, 1, 0, 3, 4, 2, 3, 1, 0, 1]), array([0, 4, 9, 5, 8, 0, 5, 0, 
# ...

# %%
predictedList=[]
for i in range(len(predictionList)):
    npArr = predictionList[i]
    for j in range(npArr.shape[0]):
        predictedList.append(npArr[j])

# %%
print(predictedList)
# Out:
# [2, 2, 1, 0, 6, 4, 3, 1, 1, 6, 1, 6, 9, 7, 4, 4, 1, 6, 3, 4, 2, 0, 1, 3, 2, 5, 4, 1, 4, 1, 6, 3, 6, 4, 6, 1, 5, 1, 1, 2, 9, 1, 6, 1, 2, 9, 1, 1, 7, 6, 9, 2, 5, 1, 8, 4, 8, 1, 7, 0, 2, 0, 2, 4, 1, 1, 6, 9, 1, 0, 0, 0, 3, 1, 1, 6, 2, 4, 3, 1, 4, 7, 2, 7, 2, 1, 7, 1, 8, 1, 0, 4, 6, 4, 6, 4, 7, 1, 7, 7, 1, 8, 2, 2, 4, 2, 1, 1, 8, 6, 3, 5, 0, 2, 3, 2, 2, 7, 0, 2, 8, 8, 1, 7, 2, 4, 3, 4, 2, 8, 6, 1, 3, 0, 8, 2, 0, 1, 7, 7, 7, 1, 4, 6, 7, 2, 1, 1, 6, 3, 1, 6, 5, 1, 9, 1, 7, 6, 4, 6, 4, 7, 3, 6, 1, 4, 1, 9, 0, 2, 7, 1, 2, 2, 1, 4, 0, 9, 6, 2, 1, 0, 0, 1, 4, 8, 3, 2, 1, 0, 2, 6, 1, 7, 7, 3, 6, 1, 1, 3, 1, 2, 3, 4, 6, 2, 1, 0, 4, 7, 1, 0, 7, 3, 7, 3, 1, 1, 1, 2, 0, 0, 7, 7, 1, 0, 4, 2, 2, 9, 2, 5, 7, 4, 1, 3, 0, 4, 5, 7, 7, 4, 0, 0, 1, 7, 2, 0, 2, 0, 7, 9, 0, 3, 0, 3, 1, 1, 2, 6, 1, 7, 4, 3, 0, 0, 4, 7, 6, 1, 7, 1, 0, 3, 4, 2, 3, 1, 0, 1, 0, 4, 9, 5, 8, 0, 5, 0, 3, 0, 3, 2, 1, 5, 5, 1, 2, 6, 6, 0, 0, 4, 8, 2, 2, 6, 8, 4, 5, 3, 2, 3, 7, 3, 6, 1, 6, 8, 7, 4, 2, 1, 4, 2, 6, 1, 6, 6, 5, 0, 4, 4, 4
# ...

# %%
from hw3_utils import shared_dataset, load_data
datasets = load_data(theano_shared=False)
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]

# %%
actualValues = []
for i in range(test_set_y.shape[0]):
    actualValues.append(test_set_y[i])
f = open('SVHN_Actual_Y_TestValues', 'wb')
cPickle.dump(actualValues, f, protocol=cPickle.HIGHEST_PROTOCOL)
f.close()

# %%
from scipy.stats import mode
data = mode([1, 2, 3, 3, 5])
print(data.mode[0])
# Out:
# 3

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20,n_epochs=1)
# Out:
# Activations used
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# ...

# %%
from hw3b import test_lenet
test_lenet(verbose=True,batch_size=20,n_epochs=100)
# Out:
# ... building the model
# Yo man
# ... training
# print(validation_frequency) = 3296
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =
